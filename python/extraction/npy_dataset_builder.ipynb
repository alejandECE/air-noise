# %% [markdown]
# ###  Created by Luis Alejandro (alejand@umich.edu)
#
# Builds datasets by creating a npy file per observation. You can customize every class by merging any aircraft types together. You can select what feature extraction process to follow with many related digital signal processing options.
#
# **Install the following packages:**
#
# pip install npTDMS<br>
# pip install mysql-connector-python<br>

# %%
import mysql.connector
import pandas as pd
from npy_dataset import AircraftFeaturesExtractor

# %%
# Connect to DB
mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    passwd = "cuba",
    database = "airnoise"
)
dbcursor = mydb.cursor()

# %% [markdown]
# ### Initial exploration on the dataset
# Here we have a count of how many measurements we have per aircraft type. However each measurement contains 12 signals sampled simultaneously. To build your own dataset from here you must pick what indexes are in what class using a dictionary as shown below.

# %%
sql = '''SELECT a.id_aircraft, a.identifier, COUNT(m.aircraft) AS observations, a.description
FROM measurements m, aircrafts a WHERE a.id_aircraft = m.aircraft AND m.quality IN (1,2,3)
GROUP BY m.aircraft ORDER BY observations;'''

dbcursor.execute(sql)
results = dbcursor.fetchall()
df = pd.DataFrame(results,columns =['aircraft', 'identifier', 'observations','description'])
df
# Out:
#     aircraft                  identifier  observations  \
# 0          3          A319-1xx (CFM56-5)             1
# 1         14              MD-8x (2JT8D2)             1
# 2         17  787-8 Dreamliner (GEnx-1B)             1
# 3         18            B767-3* (PW4060)             1
# 4         19         B747-8* (GEnx-2B67)             1
# 5         20        B747-4*(CF6-80C2B5F)             1
# 6         21           CRJ200 (CF34-3B1)             1
# 7         15              TU204 (PS-90A)             2
# 8          5           ATR42-300 (PW120)             2
# 9          7          ATR72-600 (PW127M)             3
# 10        16              SU95 (SaM 146)             3
# 11         6          ATR42-500 (PW127E)             8
# 12         8          B737-3xx (CFM56-3)             8
# 13        12        ERJ170/175 (CF34-8E)             8
# 14         4            A319-1xx (V25xx)            10
# 15         2            A320-2xx (V25xx)            11
# 16        11             ERJ145 (AE3007)            18
# 17         9       B737-8xx (CF56-7B22+)            19
# 18        13           ERJ190 (CF34-10E)            22
# 19        10       B737-7xx (CF56-7B22-)            27
# 20         1          A320-2xx (CFM56-5)            39
#
#                                           description
# 0   In the ANP only the A319-131 with V2522-A5 eng...
# 1   In the ANP aircrafts MD81, MD82 and MD83 are g...
# 2                      It does not appear in the ANP.
# 3    In the ANP appears in the acoustic class 2CF680.
# 4                      It does not appear in the ANP.
# 5                      It does not appear in the ANP.
# 6                      It does not appear in the ANP.
# 7                      It does not appear in the ANP.
# 8   In the ANP it does not appear but there is a c...
# 9                      It does not appear in the ANP.
# 10              It does not appear in the ANP. Sukoi.
# 11                     It does not appear in the ANP.
# 12  In the ANP both 737-300 and 737-3B2 appear in ...
# 13                     It does not appear in the ANP.
# 14  In the ANP appears the A319-131 with V2522-A5 ...
# 15  In the ANP the A320-232 is in the acoustic cla...
# 16  In the ANP both EMB145 and EMB14L are mapped t...
# 17  In the ANP both 737-700 and 737-800 are mapped...
# 18                     It does not appear in the ANP.
# 19  In the ANP both 737-700 and 737-800 are mapped...
# 20  In the ANP the A320-211 is in the acoustic cla...

# %% [markdown]
# ### We manually build the classes
# * Group aircrafts in different classes. You have the freedom of grouping more than one aircraft type together.

# %%
classes = {
    'Airbus': [1,2,4],
    'Boeing': [10,9]
}
builder = AircraftFeaturesExtractor(dbcursor, classes, 51200)
result = builder.build()

# %%
classes = {
    'A320-2xx (CFM56-5)': [1],
    'B737-7xx (CF56-7B22-)': [10],
    'ERJ190 (CF34-10E)': [13],
    'B737-8xx (CF56-7B22+)': [9],
    'ERJ145 (AE3007)': [11],
    'A320-2xx (V25xx)': [2],
    'A319-1xx (V25xx)': [4],
    'ERJ170-175 (CF34-8E)': [12]
}
builder = AircraftFeaturesExtractor(dbcursor, classes, 51200)
result = builder.build()

# %%
classes = {
    'A320-2xx (CFM56-5)': [1],
    'B737-7xx (CF56-7B22-)': [10],
    'ERJ190 (CF34-10E)': [13],
    'B737-8xx (CF56-7B22+)': [9],
}

builder = AircraftFeaturesExtractor(dbcursor, classes, 51200)
result = builder.build()
# Out:
# Working on class: A320-2xx (CFM56-5)
# 	Measurements included:
# 		Id: 1, URL: 2013-03-23\2.tdms
# 		Id: 6, URL: 2013-03-23\8.tdms
# 		Id: 12, URL: 2013-03-23\14.tdms
# 		Id: 13, URL: 2013-03-23\15.tdms
# 		Id: 14, URL: 2013-03-23\16.tdms
# 		Id: 17, URL: 2013-09-13\4.tdms
# 		Id: 23, URL: 2013-09-13\12.tdms
# 		Id: 25, URL: 2013-09-13\14.tdms
# 		Id: 28, URL: 2013-09-13\18.tdms
# 		Id: 31, URL: 2013-09-13\21.tdms
# 		Id: 32, URL: 2013-09-13\22.tdms
# 		Id: 34, URL: 2013-09-13\25.tdms
# 		Id: 36, URL: 2013-09-13\28.tdms
# 		Id: 37, URL: 2013-09-13\29.tdms
# 		Id: 47, URL: 2013-09-13\39.tdms
# 		Id: 50, URL: 2013-09-13\42.tdms
# 		Id: 57, URL: 2013-09-13\49.tdms
# 		Id: 58, URL: 2013-09-13\50.tdms
# 		Id: 64, URL: 2013-09-13\57.tdms
# 		Id: 68, URL: 2013-09-13\63.tdms
# 		Id: 80, URL: 2014-02-21\1.tdms
# 		Id: 81, URL: 2014-02-21\2.tdms
# 		Id: 83, URL: 2014-02-21\4.tdms
# 		Id: 93, URL: 2014-02-21\14.tdms
# 		Id: 103, URL: 2014-02-21\24.tdms
# 		Id: 104, URL: 2014-02-21\26.tdms
# 		Id: 108, URL: 2014-02-21\31.tdms
# 		Id: 113, URL: 2014-02-21\37.tdms
# 		Id: 120, URL: 2014-02-21\45.tdms
# 		Id: 126, URL: 2014-02-21\52.tdms
# 		Id: 133, URL: 2014-02-21\59.tdms
# 		Id: 140, URL: 2014-02-21\66.tdms
# 		Id: 150, URL: 2014-02-21\76.tdms
# 		Id: 157, URL: 2014-02-21\84.tdms
# 		Id: 159, URL: 2014-02-21\86.tdms
# 		Id: 172, URL: 2014-02-21\102.tdms
# 		Id: 173, URL: 2014-02-21\103.tdms
# 		Id: 179, URL: 2014-02-21\109.tdms
# 		Id: 186, URL: 2014-02-21\119.tdms
# Working on class: B737-7xx (CF56-7B22-)
# 	Measurements included:
# 		Id: 10, URL: 2013-03-23\12.tdms
# 		Id: 20, URL: 2013-09-13\9.tdms
# 		Id: 21, URL: 2013-09-13\10.tdms
# 		Id: 24, URL: 2013-09-13\13.tdms
# 		Id: 33, URL: 2013-09-13\23.tdms
# 		Id: 44, URL: 2013-09-13\36.tdms
# 		Id: 46, URL: 2013-09-13\38.tdms
# 		Id: 61, URL: 2013-09-13\53.tdms
# 		Id: 66, URL: 2013-09-13\60.tdms
# 		Id: 67, URL: 2013-09-13\62.tdms
# 		Id: 75, URL: 2013-09-13\70.tdms
# 		Id: 77, URL: 2013-09-13\72.tdms
# 		Id: 92, URL: 2014-02-21\13.tdms
# 		Id: 101, URL: 2014-02-21\22.tdms
# 		Id: 109, URL: 2014-02-21\32.tdms
# 		Id: 123, URL: 2014-02-21\48.tdms
# 		Id: 124, URL: 2014-02-21\50.tdms
# 		Id: 125, URL: 2014-02-21\51.tdms
# 		Id: 130, URL: 2014-02-21\56.tdms
# 		Id: 134, URL: 2014-02-21\60.tdms
# 		Id: 141, URL: 2014-02-21\67.tdms
# 		Id: 145, URL: 2014-02-21\71.tdms
# 		Id: 155, URL: 2014-02-21\82.tdms
# 		Id: 166, URL: 2014-02-21\94.tdms
# 		Id: 174, URL: 2014-02-21\104.tdms
# 		Id: 175, URL: 2014-02-21\105.tdms
# 		Id: 185, URL: 2014-02-21\116.tdms
# Working on class: ERJ190 (CF34-10E)
# 	Measurements included:
# 		Id: 8, URL: 2013-03-23\10.tdms
# 		Id: 18, URL: 2013-09-13\7.tdms
# 		Id: 22, URL: 2013-09-13\11.tdms
# 		Id: 38, URL: 2013-09-13\30.tdms
# 		Id: 41, URL: 2013-09-13\33.tdms
# 		Id: 42, URL: 2013-09-13\34.tdms
# 		Id: 49, URL: 2013-09-13\41.tdms
# 		Id: 56, URL: 2013-09-13\48.tdms
# 		Id: 62, URL: 2013-09-13\54.tdms
# 		Id: 79, URL: 2013-09-13\75.tdms
# 		Id: 106, URL: 2014-02-21\29.tdms
# 		Id: 114, URL: 2014-02-21\38.tdms
# 		Id: 127, URL: 2014-02-21\53.tdms
# 		Id: 129, URL: 2014-02-21\55.tdms
# 		Id: 136, URL: 2014-02-21\62.tdms
# 		Id: 146, URL: 2014-02-21\72.tdms
# 		Id: 147, URL: 2014-02-21\73.tdms
# 		Id: 153, URL: 2014-02-21\80.tdms
# 		Id: 161, URL: 2014-02-21\88.tdms
# 		Id: 162, URL: 2014-02-21\90.tdms
# 		Id: 163, URL: 2014-02-21\91.tdms
# 		Id: 164, URL: 2014-02-21\92.tdms
# Working on class: B737-8xx (CF56-7B22+)
# 	Measurements included:
# 		Id: 16, URL: 2013-09-13\2.tdms
# 		Id: 30, URL: 2013-09-13\20.tdms
# 		Id: 39, URL: 2013-09-13\31.tdms
# 		Id: 45, URL: 2013-09-13\37.tdms
# 		Id: 48, URL: 2013-09-13\40.tdms
# 		Id: 55, URL: 2013-09-13\47.tdms
